# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pong = ['Pong', 3100, False]
cod = ['Call of Duty', 3200, True]
snake = ['Snake', 1500, True]
tetris = ['Tetris', 2000, False]
space_invaders = ['Space Invaders', 2500, True]
flappy_bird = ['Flappy Bird', 1800, False]
arkanoid = ['Arkanoid', 2200, True]
pacman = ['Pac-Man', 2700, True]
ahorcado = ['Ahorcado', 1200, False]
tres_en_raya = ['Tres en Raya', 1300, True]
carrera_coches = ['Carrera de coches 2D', 3000, False]
memoria = ['Juego de memoria', 1600, True]
simon_dice = ['Simon Dice', 1400, False]
damas = ['Damas', 1700, True]
ajedrez = ['Ajedrez', 2800, True]
plataformas = ['Juego de plataformas', 2600, False]
laberinto = ['Laberinto', 2100, True]
shooter = ['Shooter 2D', 2900, True]
pesca = ['Juego de pesca', 1500, False]
rpg_texto = ['RPG de texto', 2400, True]

# %%
nombrev =[pong, cod, snake, tetris, space_invaders, flappy_bird, arkanoid,
                pacman, ahorcado, tres_en_raya, carrera_coches, memoria, simon_dice,
                damas, ajedrez, plataformas, laberinto, shooter, pesca, rpg_texto]

# %%
df = pd.DataFrame(nombrev, columns=['Nombre', 'Usuarios', 'Pertenece a Meta'])

# %%
nombrev[4]
# Out:
# ['Space Invaders', 2500, True]

# %%
nombrev[2:6]
# Out:
# [['Snake', 1500, True],
#  ['Tetris', 2000, False],
#  ['Space Invaders', 2500, True],
#  ['Flappy Bird', 1800, False]]

# %%
resumen = df['Usuarios(millones)'].describe()

# %%
print(resumen)
# Out:
# count      20.000000
# mean     2175.000000
# std       652.021149
# min      1200.000000
# 25%      1575.000000
# 50%      2150.000000
# 75%      2725.000000
# max      3200.000000
# Name: Usuarios(millones), dtype: float64

# %%
plt.bar(df['Nombre'],df['Usuarios'])
plt.show()

# %%
plt.plot(df['Nombre'],df['Usuarios'], label= 'linea')
